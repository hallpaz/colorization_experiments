# %%
# import resources
# %matplotlib inline

from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

import torch
import torch.optim as optim
from torchvision import transforms, models

from scipy.misc import imsave, imread

# %%
def load_image(img_path, max_size=400, shape=None):
    ''' Load in and transform an image, making sure the image
       is <= 400 pixels in the x-y dims.'''
    
    image = Image.open(img_path).convert('RGB')
    
    # large images will slow down processing
    if max(image.size) > max_size:
        size = max_size
    else:
        size = max(image.size)
    
    if shape is not None:
        size = shape
        
    in_transform = transforms.Compose([
                        transforms.Resize(size),
                        transforms.ToTensor(),
                        transforms.Normalize((0.485, 0.456, 0.406), 
                                             (0.229, 0.224, 0.225))
    ])

    # discard the transparent, alpha channel (that's the :3) and add the batch dimension
    image = in_transform(image)[:3,:,:].unsqueeze(0)
    
    return image

# helper function for un-normalizing an image 
# and converting it from a Tensor image to a NumPy image for display
def im_convert(tensor):
    """ Display a tensor as an image. """
    
    image = tensor.to("cpu").clone().detach()
    image = image.numpy().squeeze()
    image = image.transpose(1,2,0)
    image = image * np.array((0.229, 0.224, 0.225)) + np.array((0.485, 0.456, 0.406))
    image = image.clip(0, 1)

    return image

def im_denormalize(numpyimg):
    image = numpyimg.squeeze()
    image = image.transpose(1,2,0)
    image = image * np.array((0.229, 0.224, 0.225)) + np.array((0.485, 0.456, 0.406))
    image = image.clip(0, 1)
    return image

def to_needed_numpy(tensor):
    shape = tensor.shape
    tensor.view(3, shape[2], shape[3])

# %%
#imsrc = imread("images/octopus.jpg")
#imtint = imread("images/ben_passmore.jpg")

imsrc = load_image("images/kahlo.jpg")
imtint = load_image("images/hockney.jpg")

# %%
imsrc.shape
# Out:
# torch.Size([1, 3, 400, 480])

# %%
imsrc[0][0]
# Out:
# tensor([[-0.7650, -0.7479, -0.7479,  ...,  0.6392,  0.5707,  0.5707],
#         [-0.7822, -0.8849, -0.8849,  ...,  0.5193,  0.5707,  0.5707],
#         [-0.8335, -0.8507, -0.9705,  ...,  0.5193,  0.5193,  0.5707],
#         ...,
#         [-1.5528, -1.5870, -1.5870,  ..., -1.6898, -1.8097, -1.8439],
#         [-1.5185, -1.5357, -1.5699,  ..., -1.6555, -1.7754, -1.8439],
#         [-1.2617, -1.4158, -1.6384,  ..., -1.5528, -1.7240, -1.7754]])

# %%
# imres = match_histogram(im_convert(imsrc), im_convert(imtint))
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(20, 10))
# content and style ims side-by-side
ax1.imshow(im_convert(imsrc)[:,:,0], cmap='gray')
ax2.imshow(im_convert(imsrc)[:,:,1], cmap='gray')
ax3.imshow(im_convert(imsrc)[:,:,2], cmap='gray')

# %%
plt.imshow(im_convert(imsrc))

# %%
hop = torch.Tensor(np.array([[0.21], [0.72], [0.07]])).unsqueeze(0)
imsrc.dot(hop)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-61-22392714cae2> in <module>()
#       1 hop = torch.Tensor(np.array([[0.21], [0.72], [0.07]])).unsqueeze(0)
# ----> 2 imsrc.dot(hop)
#
# RuntimeError: dot: Expected 1-D argument self, but got 4-D

# %%
def get_luminance(tensor):
    image = im_convert(tensor)
    image = imsrc[:,:,0]*0.21 + imsrc[:,:,1]*0.72 + imsrc[:,:,2]*0.07
    return image

# %%
def get_luminance_tensor(tensor):
    res = tensor[0][0]*0.21 + tensor[0][1]*0.72 + tensor[0][2]*0.07
    return res.unsqueeze(0).unsqueeze(0)

# %%
hop1 = get_luminance(imsrc)
hop2 = get_luminance(imsrc)
torch.mean((hop1-hop2)**2)
# Out:
# tensor(0.)

# %%
grayscale = imsrc[0][0]*0.21 + imsrc[0][1]*0.72 + imsrc[0][2]*0.07
# grayscale = grayscale.unsqueeze(0).unsqueeze(0)
print(grayscale.shape)
grayscale
# Out:
# torch.Size([400, 480])
# tensor([[-0.1551, -0.0974, -0.0559,  ...,  1.0559,  1.0265,  1.0265],
#         [-0.1713, -0.2481, -0.1928,  ...,  0.9490,  1.0139,  1.0265],
#         [-0.2223, -0.2109, -0.2775,  ...,  0.9490,  0.9629,  1.0151],
#         ...,
#         [-1.5160, -1.5508, -1.5508,  ..., -1.7672, -1.8362, -1.8308],
#         [-1.4811, -1.5111, -1.5334,  ..., -1.7461, -1.8014, -1.8308],
#         [-1.2174, -1.3868, -1.6145,  ..., -1.6416, -1.7756, -1.7750]])

# %%
plt.imshow(grayscale, cmap='gray')

# %%
plt.imshow(im_convert(grayscale), cmap='gray')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-62-128169f88bbd> in <module>()
# ----> 1 plt.imshow(im_convert(grayscale), cmap='gray')
#
# <ipython-input-31-138406bcc29a> in im_convert(tensor)
#      33     image = tensor.to("cpu").clone().detach()
#      34     image = image.numpy().squeeze()
# ---> 35     image = image.transpose(1,2,0)
#      36     image = image * np.array((0.229, 0.224, 0.225)) + np.array((0.485, 0.456, 0.406))
#      37     image = image.clip(0, 1)
#
# ValueError: axes don't match array

# %%
imsrc[0][0] = imsrc[0][0]*10
imsrc[0][0]
# Out:
# tensor([[ -4.3968,  -4.3968,  -4.3968,  ...,  -8.5067,  -7.4792,  -6.7942],
#         [ -5.0818,  -4.9105,  -4.9105,  ...,   2.9669,   4.5081,   5.0218],
#         [ -5.9380,  -5.5955,  -5.2530,  ...,  15.1254,  16.8379,  16.6667],
#         ...,
#         [-18.7816, -17.0691, -15.3566,  ..., -19.4666, -19.4666, -19.6378],
#         [-17.2403, -16.5554, -15.3566,  ..., -19.2953, -19.2953, -19.6378],
#         [-15.6991, -15.5279, -14.8429,  ..., -18.7816, -19.1241, -19.8091]])

# %%
hop = im_convert(imtint)
print(hop.shape)
# Out:
# (360, 263, 3)

# %%
hop = hop.dot([0.07, 0.72, 0.21])
print(hop.shape)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-dfff825bd196> in <module>()
# ----> 1 hop = hop.dot([0.07, 0.72, 0.21])
#       2 hop = hop.squeeze(0)
#       3 print(hop.shape)
#
# ValueError: shapes (360,263) and (3,) not aligned: 263 (dim 1) != 3 (dim 0)

# %%
plt.imshow(hop)

# %%
convertida = im_convert(imsrc)
print(convertida[2][20][0], convertida[2][20][1], convertida[2][20][2])
# Out:
# 0.513725504413247 0.5137255201339722 0.5137255338430405

# %%
print(imsrc[0][0][2][20], imsrc[0][1][2][20], imsrc[0][2][2][20])
# Out:
# tensor(0.1254) tensor(0.2577) tensor(0.4788)

# %%
#teste = imsrc.view(3, 400, 592).numpy().transpose(1, 2, 0)
im_denormalize(imsrc.numpy()).shape
# Out:
# (400, 592, 3)

# %%
def match_histogram(imsrc, imtint, nbr_bins=255):
    if len(imsrc.shape) < 3:
        imsrc = imsrc[:,:,np.newaxis]
        imtint = imtint[:,:,np.newaxis]

    imres = imsrc.copy()
    for d in range(imsrc.shape[2]):
        imhist,bins = np.histogram(imsrc[:,:,d].flatten(),nbr_bins,normed=True)
        tinthist,bins = np.histogram(imtint[:,:,d].flatten(),nbr_bins,normed=True)

        cdfsrc = imhist.cumsum() #cumulative distribution function
        cdfsrc = (255 * cdfsrc / cdfsrc[-1]).astype(np.uint8) #normalize

        cdftint = tinthist.cumsum() #cumulative distribution function
        cdftint = (255 * cdftint / cdftint[-1]).astype(np.uint8) #normalize


        im2 = np.interp(imsrc[:,:,d].flatten(),bins[:-1],cdfsrc)



        im3 = np.interp(im2,cdftint, bins[:-1])

        imres[:,:,d] = im3.reshape((imsrc.shape[0],imsrc.shape[1] ))
        
    return imres

# %%
imres = match_histogram(imsrc, imtint)
try:
    imsave("histnormresult3.jpg", imres)
except:
    imsave("histnormresult3.jpg", imres.reshape((imsrc.shape[0],imsrc.shape[1] )))
# Out:
# /Users/hallpaz/Workspace/deep_env/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
imres = match_histogram(im_convert(imsrc), im_convert(imtint))
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(20, 10))
# content and style ims side-by-side
ax1.imshow(im_convert(imsrc))
ax2.imshow(im_convert(imtint))
ax3.imshow(imres)

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(20, 10))
# content and style ims side-by-side
ax1.imshow(imsrc)
ax2.imshow(imtint)
ax3.imshow(imres)

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(20, 10))
# content and style ims side-by-side
ax1.imshow(imsrc)
ax2.imshow(imtint)
ax3.imshow(imres)
